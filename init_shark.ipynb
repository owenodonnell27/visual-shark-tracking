# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import os

print(tf.__version__)
print(os.listdir('./images'))
# Out:
# 2.9.1
# ['test', 'train', 'val']

# %%
# Constants
FAST_RUN = False
IMAGE_WIDTH=256
IMAGE_HEIGHT=256
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Prep Training Data

# %%
filenames = os.listdir("./images/train/shark")
filenames += os.listdir("./images/train/non-shark")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category in ('great_white_shark', 'hammerhead', 'tiger_shark'):
        categories.append(1)
    else:
        categories.append(0)

train_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
earlystop = EarlyStopping(patience=10)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %%
train_df["category"] = train_df["category"].replace({0: 'non-shark', 1: 'shark'})

# %% [markdown]
# # Prep Validation Data

# %%
filenames = os.listdir("./images/val/shark")
filenames += os.listdir("./images/val/non-shark")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category in ('great_white_shark', 'hammerhead', 'tiger_shark'):
        categories.append(1)
    else:
        categories.append(0)

validate_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
validate_df["category"] = validate_df["category"].replace({0: 'non-shark', 1: 'shark'})

# %% [markdown]
# # Finish Preparing Data

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# # Create Model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 254, 254, 32)      896
#
#  batch_normalization_12 (Bat  (None, 254, 254, 32)     128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  dropout_12 (Dropout)        (None, 127, 127, 32)      0
#
#  conv2d_10 (Conv2D)          (None, 125, 125, 64)      18496
#
#  batch_normalization_13 (Bat  (None, 125, 125, 64)     256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 62, 62, 64)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 62, 62, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 60, 60, 128)       73856
#
#  batch_normalization_14 (Bat  (None, 60, 60, 128)      512
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 30, 30, 128)      0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 30, 30, 128)       0
#
#  flatten_3 (Flatten)         (None, 115200)            0
#
#  dense_6 (Dense)             (None, 512)               58982912
#
#  batch_normalization_15 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 59,080,130
# Trainable params: 59,078,658
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_directory(
    "./images/train/", 
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size,
)
# Out:
# Found 6039 images belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory( 
    "./images/val/", 
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 1707 images belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "./images/train/non-shark/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Train and Test Model

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# C:\Users\odonn\AppData\Local\Temp\ipykernel_20552\612699584.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# 402/402 [==============================] - ETA: 0s - loss: 0.7944 - accuracy: 0.6814WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 541s 1s/step - loss: 0.7944 - accuracy: 0.6814 - val_loss: 0.5982 - val_accuracy: 0.6684 - lr: 0.0010
# Epoch 2/50
# 402/402 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7384WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 534s 1s/step - loss: 0.5606 - accuracy: 0.7384 - val_loss: 0.5559 - val_accuracy: 0.7215 - lr: 0.0010
# Epoch 3/50
# 402/402 [==============================] - ETA: 0s - loss: 0.5270 - accuracy: 0.7610WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.5270 - accuracy: 0.7610 - val_loss: 0.4699 - val_accuracy: 0.8018 - lr: 0.0010
# Epoch 4/50
# 402/402 [==============================] - ETA: 0s - loss: 0.5124 - accuracy: 0.7739WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 523s 1s/step - loss: 0.5124 - accuracy: 0.7739 - val_loss: 0.4776 - val_accuracy: 0.7876 - lr: 0.0010
# Epoch 5/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7847WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.4936 - accuracy: 0.7847 - val_loss: 0.5350 - val_accuracy: 0.7263 - lr: 0.0010
# Epoch 6/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4988 - accuracy: 0.7724WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 522s 1s/step - loss: 0.4988 - accuracy: 0.7724 - val_loss: 0.4256 - val_accuracy: 0.8319 - lr: 0.0010
# Epoch 7/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.7860WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 522s 1s/step - loss: 0.4843 - accuracy: 0.7860 - val_loss: 0.3857 - val_accuracy: 0.8454 - lr: 0.0010
# Epoch 8/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.7860WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.4843 - accuracy: 0.7860 - val_loss: 0.4572 - val_accuracy: 0.8142 - lr: 0.0010
# Epoch 9/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.7907WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4810 - accuracy: 0.7907 - val_loss: 0.9907 - val_accuracy: 0.6136 - lr: 0.0010
# Epoch 10/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.7966WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 518s 1s/step - loss: 0.4583 - accuracy: 0.7966 - val_loss: 0.5265 - val_accuracy: 0.7233 - lr: 0.0010
# Epoch 11/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.7943WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4679 - accuracy: 0.7943 - val_loss: 0.4022 - val_accuracy: 0.8271 - lr: 0.0010
# Epoch 12/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.8108WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4483 - accuracy: 0.8108 - val_loss: 0.4435 - val_accuracy: 0.8206 - lr: 0.0010
# Epoch 13/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4467 - accuracy: 0.8036WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 518s 1s/step - loss: 0.4467 - accuracy: 0.8036 - val_loss: 0.5013 - val_accuracy: 0.7540 - lr: 0.0010
# Epoch 14/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.7985WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.4541 - accuracy: 0.7985 - val_loss: 0.5555 - val_accuracy: 0.7770 - lr: 0.0010
# Epoch 15/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.7976WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 521s 1s/step - loss: 0.4513 - accuracy: 0.7976 - val_loss: 0.4324 - val_accuracy: 0.8460 - lr: 0.0010
# Epoch 16/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.8121WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.4361 - accuracy: 0.8121 - val_loss: 0.3776 - val_accuracy: 0.8360 - lr: 0.0010
# Epoch 17/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4451 - accuracy: 0.8083WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4451 - accuracy: 0.8083 - val_loss: 0.4126 - val_accuracy: 0.8183 - lr: 0.0010
# Epoch 18/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.8108WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4366 - accuracy: 0.8108 - val_loss: 0.5309 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 19/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8127WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 518s 1s/step - loss: 0.4356 - accuracy: 0.8127 - val_loss: 0.4987 - val_accuracy: 0.8088 - lr: 0.0010
# Epoch 20/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8181WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4327 - accuracy: 0.8181 - val_loss: 0.3920 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 21/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4429 - accuracy: 0.8096WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 521s 1s/step - loss: 0.4429 - accuracy: 0.8096 - val_loss: 0.4818 - val_accuracy: 0.7687 - lr: 0.0010
# Epoch 22/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.8204WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 518s 1s/step - loss: 0.4195 - accuracy: 0.8204 - val_loss: 0.4149 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 23/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.8217WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.4170 - accuracy: 0.8217 - val_loss: 0.4181 - val_accuracy: 0.8024 - lr: 0.0010
# Epoch 24/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4200 - accuracy: 0.8184WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 518s 1s/step - loss: 0.4200 - accuracy: 0.8184 - val_loss: 0.4396 - val_accuracy: 0.7900 - lr: 0.0010
# Epoch 25/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4242 - accuracy: 0.8237WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 520s 1s/step - loss: 0.4242 - accuracy: 0.8237 - val_loss: 0.5150 - val_accuracy: 0.7381 - lr: 0.0010
# Epoch 26/50
# 402/402 [==============================] - ETA: 0s - loss: 0.4184 - accuracy: 0.8214WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 402/402 [==============================] - 519s 1s/step - loss: 0.4184 - accuracy: 0.8214 - val_loss: 0.3957 - val_accuracy: 0.8419 - lr: 0.0010

# %%
model.save_weights("model.h5")

# %%
model.load_weights("model.h5")
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
test_filenames = os.listdir("./images/test/shark")
test_filenames += os.listdir("./images/test/non-shark")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_directory(
    "./images/test/", 
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 1943 images belonging to 2 classes.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# C:\Users\odonn\AppData\Local\Temp\ipykernel_20552\3090721588.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %%
test_df['category'].value_counts().plot.bar()
print(test_df['category'].value_counts())
# Out:
# category
# non-shark    1123
# shark         820
# Name: count, dtype: int64

# %%
shark_correct = 0
shark_total = 0
non_shark_correct = 0
non_shark_total = 0
for i in range(len(test_df['category'])):
    # Predicted shark correctly
    if test_df['filename'][i].split('.')[0] in ('great_white_shark', 'hammerhead', 'tiger_shark') and test_df['category'][i] == 'shark':
        shark_correct += 1
        shark_total += 1
    elif test_df['filename'][i].split('.')[0] in ('great_white_shark', 'hammerhead', 'tiger_shark') and test_df['category'][i] == 'non-shark':
        shark_total += 1
    elif test_df['filename'][i].split('.')[0] not in ('great_white_shark', 'hammerhead', 'tiger_shark') and test_df['category'][i] == 'non-shark':
        non_shark_correct += 1
        non_shark_total += 1
    else:
        non_shark_total += 1

print('Sharks:', round(shark_correct/shark_total, 3) * 100, '%', sep='')
print('Non-sharks:', round(non_shark_correct/non_shark_total, 3) * 100)
print('Total:', round((shark_correct+non_shark_correct)/(shark_total+non_shark_total), 3) * 100)
# Out:
# Sharks:14.7%
# Non-sharks: 35.3
# Total: 26.0
